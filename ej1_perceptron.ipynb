# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./data/TP3-1.csv")
df
# Out:
#            X         Y  Label
# 0   4.251033  0.888220     -1
# 1   0.350428  1.476792      1
# 2   4.126401  3.059509     -1
# 3   3.255059  3.870984     -1
# 4   4.061885  4.636752     -1
# ..       ...       ...    ...
# 95  2.295126  3.398279     -1
# 96  3.677961  2.733900     -1
# 97  3.906481  0.060928     -1
# 98  2.110758  1.191714     -1
# 99  1.077604  3.639321      1
#
# [100 rows x 3 columns]

# %%
data_ls = df.to_numpy()
data_ls
# Out:
# array([[ 4.25103322,  0.88821995, -1.        ],
#        [ 0.35042828,  1.47679232,  1.        ],
#        [ 4.12640143,  3.05950914, -1.        ],
#        [ 3.25505896,  3.87098404, -1.        ],
#        [ 4.061885  ,  4.63675188, -1.        ],
#        [ 0.16422252,  1.7440822 ,  1.        ],
#        [ 1.4499632 ,  0.22378188, -1.        ],
#        [ 3.5820819 ,  3.0882839 , -1.        ],
#        [ 1.34602076,  2.64991743,  1.        ],
#        [ 1.86294961,  0.44258907, -1.        ],
#        [ 1.44939825,  4.56275813,  1.        ],
#        [ 0.65072947,  0.95688347,  1.        ],
#        [ 4.60687432,  0.16744572, -1.        ],
#        [ 2.79432084,  0.33979484, -1.        ],
#        [ 4.57860133,  3.85184228, -1.        ],
#        [ 3.77734965,  3.85074681, -1.        ],
#        [ 2.63623075,  1.25339247, -1.        ],
#        [ 4.03598082,  2.63807395, -1.        ],
#        [ 1.34037574,  0.40501201, -1.        ],
#        [ 4.20744456,  1.53139682, -1.        ],
#        [ 4.55828846,  0.08662126, -1.        ],
#        [ 4.73922404,  2.21946683, -1.        ],
#        [ 4.4283276 ,  2.09769584, -1.        ],
#        [ 0.01339443,  1.04284522,  1.        ],
#        [ 4.35389347,  2.80146033, -1.        ],
#        [ 0.18836241,  4.01830824,  1.        ],
#        [ 0.76182431,  3.33975198,  1.        ],
#        [ 4.98371012,  1.78507832, -1.        ],
#        [ 2.60638771,  0.67855785, -1.        ],
#        [ 2.23856256,  3.5564057 , -1.        ],
#        [ 1.404414  ,  4.1733945 ,  1.        ],
#        [ 2.06902268,  4.64268894,  1.        ],
#        [ 2.81131192,  3.23575313, -1.        ],
#        [ 2.2268173 ,  3.08678664, -1.        ],
#        [ 3.23195536,  2.63904769, -1.        ],
#        [ 1.6061607 ,  0.20298038, -1.        ],
#        [ 0.84743949,  3.17536879,  1.        ],
#        [ 3.90451732,  0.27616371, -1.        ],
#        [ 2.55278544,  0.25152285, -1.        ],
#        [ 3.85975973,  3.24543851, -1.        ],
#        [ 1.99122197,  3.48248703, -1.        ],
#        [ 1.14854541,  3.56898133,  1.        ],
#        [ 2.00638649,  4.47848887,  1.        ],
#        [ 3.11695517,  1.05917571, -1.        ],
#        [ 0.23586285,  4.46106103,  1.        ],
#        [ 0.39380789,  4.89492154,  1.        ],
#        [ 1.7021903 ,  2.47931907, -1.        ],
#        [ 1.73149232,  0.75166624, -1.        ],
#        [ 0.20339681,  3.64198293,  1.        ],
#        [ 1.50873081,  2.91126768,  1.        ],
#        [ 0.32561594,  4.52311072,  1.        ],
#        [ 1.80335222,  1.8251911 , -1.        ],
#        [ 4.20258213,  1.43423145, -1.        ],
#        [ 3.25503608,  0.86782523, -1.        ],
#        [ 4.66633902,  1.82950332, -1.        ],
#        [ 2.47934313,  1.56264343, -1.        ],
#        [ 4.63231632,  0.57235331, -1.        ],
#        [ 4.4692266 ,  0.58392981, -1.        ],
#        [ 4.27397825,  3.96798902, -1.        ],
#        [ 2.74716147,  1.69475333, -1.        ],
#        [ 2.52437304,  2.41750552, -1.        ],
#        [ 4.52640203,  0.02835122, -1.        ],
#        [ 3.94231503,  3.48971309, -1.        ],
#        [ 3.52180156,  3.768013  , -1.        ],
#        [ 4.85032527,  4.73217742, -1.        ],
#        [ 2.30133433,  4.33636293, -1.        ],
#        [ 2.01007261,  4.73876073,  1.        ],
#        [ 0.24041495,  3.03844014,  1.        ],
#        [ 0.4579997 ,  4.97518085,  1.        ],
#        [ 0.98057896,  1.17283319,  1.        ],
#        [ 1.12192894,  1.47947176,  1.        ],
#        [ 0.67749899,  0.11261596,  1.        ],
#        [ 1.08273771,  2.70870507,  1.        ],
#        [ 3.79144613,  1.06743734, -1.        ],
#        [ 2.07147851,  2.18089595, -1.        ],
#        [ 1.63167784,  4.98396174,  1.        ],
#        [ 3.84879753,  4.57792474, -1.        ],
#        [ 3.42154824,  0.68441544, -1.        ],
#        [ 1.85171035,  0.89453883, -1.        ],
#        [ 4.51975997,  2.12291057, -1.        ],
#        [ 2.77852486,  3.01970879, -1.        ],
#        [ 2.84722164,  4.742714  , -1.        ],
#        [ 4.11294263,  3.02230526, -1.        ],
#        [ 2.2127847 ,  0.8968853 , -1.        ],
#        [ 2.42403545,  2.90566219, -1.        ],
#        [ 1.01015233,  3.43998232,  1.        ],
#        [ 4.65536908,  4.50126345, -1.        ],
#        [ 1.58811676,  3.87792801,  1.        ],
#        [ 3.11665238,  0.31937641, -1.        ],
#        [ 4.14064928,  0.2561552 , -1.        ],
#        [ 0.28863119,  3.42944277,  1.        ],
#        [ 0.37436652,  2.00713901,  1.        ],
#        [ 4.54849251,  3.01907054, -1.        ],
#        [ 4.22729875,  2.9694796 , -1.        ],
#        [ 2.69866536,  4.5718912 , -1.        ],
#        [ 2.29512623,  3.39827853, -1.        ],
#        [ 3.67796128,  2.73390043, -1.        ],
#        [ 3.90648085,  0.06092793, -1.        ],
#        [ 2.11075768,  1.19171409, -1.        ],
#        [ 1.07760388,  3.63932056,  1.        ]])

# %%
class_A = [(x, y) for x, y, label in data_ls if label == 1]
class_B = [(x, y) for x, y, label in data_ls if label == -1]
display(class_A, class_B)
# Out:
# [(0.3504282796511848, 1.4767923242886216),
#  (0.1642225232604022, 1.7440821955414227),
#  (1.346020761545725, 2.6499174303820574),
#  (1.449398254791085, 4.562758133660369),
#  (0.6507294705496608, 0.956883470650446),
#  (0.013394428324428, 1.0428452224277918),
#  (0.1883624121422167, 4.018308237844028),
#  (0.7618243145916204, 3.3397519823746857),
#  (1.4044139991048987, 4.173394500146047),
#  (2.06902267516336, 4.6426889427648295),
#  (0.8474394928311879, 3.17536878595786),
#  (1.1485454060937037, 3.5689813325383706),
#  (2.006386494308908, 4.478488874078467),
#  (0.2358628452375305, 4.461061027231044),
#  (0.3938078921630739, 4.894921542533312),
#  (0.203396813921361, 3.641982926566109),
#  (1.5087308121193077, 2.911267677045738),
#  (0.3256159424356525, 4.523110724231487),
#  (2.0100726112822094, 4.738760733602586),
#  (0.2404149538291683, 3.0384401370469005),
#  (0.4579997020024945, 4.975180852021773),
#  (0.98057896234651, 1.1728331900121058),
#  (1.1219289426204375, 1.479471759012148),
#  (0.6774989943503362, 0.1126159560191047),
#  (1.0827377137868863, 2.7087050658714174),
#  (1.6316778438886836, 4.983961736575837),
#  (1.010152330251572, 3.4399823184232674),
#  (1.588116755766131, 3.877928005016964),
#  (0.288631188182829, 3.4294427731634007),
#  (0.3743665244961597, 2.0071390120650583),
#  (1.0776038778900827, 3.639320555316527)]
# [(4.251033218874792, 0.888219946414105),
#  (4.126401427758181, 3.059509142672046),
#  (3.2550589616537207, 3.870984044659272),
#  (4.061884995134334, 4.636751884937615),
#  (1.4499632032695249, 0.2237818762271998),
#  (3.582081899545831, 3.0882839046044186),
#  (1.86294960811662, 0.4425890716310554),
#  (4.606874323745779, 0.1674457167608217),
#  (2.794320839360407, 0.3397948408936863),
#  (4.578601332500215, 3.8518422775273415),
#  (3.7773496473234114, 3.85074681176788),
#  (2.6362307528031383, 1.253392467750862),
#  (4.035980817402172, 2.6380739484614173),
#  (1.3403757441234754, 0.4050120085568215),
#  (4.207444557258443, 1.5313968178543902),
#  (4.558288464807417, 0.0866212588796849),
#  (4.739224037132528, 2.219466829353736),
#  (4.428327599628102, 2.0976958416143336),
#  (4.353893469230349, 2.80146032647858),
#  (4.983710119303322, 1.7850783248507511),
#  (2.606387705459891, 0.6785578480604015),
#  (2.2385625566894287, 3.55640569888048),
#  (2.811311915611514, 3.2357531250053366),
#  (2.226817300286629, 3.086786643620112),
#  (3.2319553629583124, 2.6390476936027136),
#  (1.606160702022692, 0.2029803798922574),
#  (3.904517317747902, 0.2761637052033233),
#  (2.5527854378749533, 0.251522853213259),
#  (3.859759732651512, 3.245438506779436),
#  (1.991221969022439, 3.482487028525529),
#  (3.116955167138608, 1.059175709968312),
#  (1.7021903021655072, 2.479319065284144),
#  (1.7314923177717216, 0.751666241738313),
#  (1.8033522189247573, 1.8251911044326024),
#  (4.202582134400148, 1.4342314456723688),
#  (3.2550360800059, 0.8678252262472608),
#  (4.666339020436598, 1.8295033152966853),
#  (2.4793431253909364, 1.562643432678873),
#  (4.632316320084292, 0.5723533072686277),
#  (4.4692265962144, 0.5839298109101981),
#  (4.273978253400825, 3.9679890201203656),
#  (2.747161471700856, 1.694753328951237),
#  (2.5243730388264867, 2.4175055242409726),
#  (4.526402032097021, 0.0283512173734995),
#  (3.9423150250677583, 3.4897130923203923),
#  (3.5218015584115485, 3.768012999078501),
#  (4.850325265269228, 4.732177417570009),
#  (2.301334333199867, 4.336362928980498),
#  (3.7914461315174304, 1.0674373385303304),
#  (2.071478506763329, 2.180895945137346),
#  (3.848797529643997, 4.577924740466272),
#  (3.4215482429294277, 0.6844154376902661),
#  (1.8517103457287936, 0.8945388260796344),
#  (4.519759972729636, 2.122910565873321),
#  (2.778524861317073, 3.0197087944530594),
#  (2.847221636722245, 4.742714003583398),
#  (4.112942631922495, 3.022305257080921),
#  (2.2127847029823537, 0.8968852967840446),
#  (2.424035450853657, 2.905662193595144),
#  (4.655369079029234, 4.501263447597543),
#  (3.116652379798709, 0.3193764067299043),
#  (4.14064927732759, 0.2561551987670174),
#  (4.548492507558923, 3.0190705404528058),
#  (4.227298750732012, 2.969479604758563),
#  (2.698665362245168, 4.571891201814139),
#  (2.29512623402036, 3.398278526065221),
#  (3.67796127956821, 2.733900433053773),
#  (3.906480846093357, 0.0609279308672022),
#  (2.1107576825614056, 1.191714092793709)]

# %%
class_A_x, class_A_y = zip(*class_A)
class_B_x, class_B_y = zip(*class_B)

# %%
#sns.set_style("darkgrid")
plt.figure(figsize=(10, 6))
plt.scatter(class_A_x, class_A_y, c='b', marker='o', label='Clase A')
plt.scatter(class_B_x, class_B_y, c='r', marker='x', label='Clase B')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
plt.title('Datos Linealmente Separables')
plt.show()

# %%
import pandas as pd

# %%
from utils.perceptron import build_step_perceptron

# %%
from utils.data_split import k_fold_split

# %%
train_df, test_df = k_fold_split(df, 4)

# %%
train_df.shape[0]
# Out:
# 75

# %%
p, errs, t_errs, init_w = build_step_perceptron(train_df, test_df, "Label", 0.001, iters=100000)

# %%
plt.figure(figsize=(10, 6))
#sns.set_style("darkgrid")
plt.plot(list(range(len(errs))), errs, label="Train")
plt.plot(list(range(len(t_errs))), t_errs, label="Test")
rangey = max(errs) - min(errs)
plt.ylim((0 - 0.05 * rangey, max(errs) + 0.05 * rangey))
plt.xlabel("Iteración")
plt.ylabel("Error cuadrático medio")
plt.title("Error en función de las iteraciones")
plt.legend(title="Tipo", bbox_to_anchor=(1.04, 1), loc="upper left")
plt.show()

# %%
line_x = np.linspace(0, 5, 20, True)
line_y = np.zeros(line_x.shape)
for i in range(line_x.shape[0]):
    line_y[i] = -(p.w[0][0]/p.w[0][1])*line_x[i] - (p.w[0][2]/p.w[0][1])

# %%
plt.figure(figsize=(10, 6))
#sns.set_style("darkgrid")
sns.scatterplot(train_df, x="X", y="Y", hue="Label", palette=sns.color_palette(None, 2), s=50)
sns.scatterplot(test_df, x="X", y="Y", hue="Label", palette=sns.color_palette(None, 2), s=50, marker="^", legend=False)

ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

plt.plot(line_x, line_y, color="green")

#yrange = train_df["Y"].max() - train_df["Y"].min()
#plt.ylim((train_df["Y"].min() - 0.05 * yrange, train_df["Y"].max() + 0.05 * yrange))
plt.ylim(ylim)

#xrange = train_df["X"].max() - train_df["X"].min()
#plt.xlim((train_df["X"].min() - 0.05 * xrange, train_df["X"].max() + 0.05 * xrange))
plt.xlim(xlim)

plt.xlabel("X")
plt.ylabel("Y")
plt.legend(title="Etiqueta", bbox_to_anchor=(1.04, 1), loc="upper left")
plt.title("Recta de separación del Perceptrón")
plt.show()

# %%
from utils.line_utils import maximize_step_perceptron_line_margin

# %%
max_p, max_p_margin, points, chosen_points, selected_points = maximize_step_perceptron_line_margin(train_df, "Label", p, points2decide=8)

# %%
from utils.line_utils import Line

# %%
line = Line(p.w)

# %%
max_p_margin
# Out:
# 0.26719471954667207

# %%
chosen_points_pos_df = pd.DataFrame(chosen_points[0])
chosen_points_neg_df = pd.DataFrame(chosen_points[1])
display(chosen_points_pos_df, chosen_points_neg_df)
# Out:
#           0         1
# 0  2.006386  4.478489
# 1  1.121929  1.479472
#           0         1
# 0  2.238563  3.556406

# %%
sel_points_pos_df = pd.DataFrame(selected_points[0])
sel_points_neg_df = pd.DataFrame(selected_points[1])
display(sel_points_pos_df, sel_points_neg_df)
# Out:
#           0         1
# 0  2.006386  4.478489
# 1  1.346021  2.649917
# 2  1.121929  1.479472
# 3  0.677499  0.112616
# 4  1.508731  2.911268
#           0         1
# 0  2.238563  3.556406
# 1  1.702190  2.479319
# 2  1.991222  3.482487

# %%
plt.figure(figsize=(10, 6))
#sns.set_style("darkgrid")
sns.scatterplot(train_df, x="X", y="Y", hue="Label", palette=sns.color_palette(None, 2), s=50)
sns.scatterplot(test_df, x="X", y="Y", hue="Label", palette=sns.color_palette(None, 2), s=50, marker="^", legend=False)
sns.scatterplot(sel_points_pos_df, x=0, y=1, color="red", s=50)
sns.scatterplot(sel_points_neg_df, x=0, y=1, color="blue", s=50)
sns.scatterplot(chosen_points_pos_df, x=0, y=1, color="black", marker="x", s=80)
sns.scatterplot(chosen_points_neg_df, x=0, y=1, color="black", marker="x", s=80)

ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

line_x = np.linspace(0, 5, 20, True)
line_y = np.zeros(line_x.shape)
for i in range(line_x.shape[0]):
    line_y[i] = -(max_p.w[0][0]/max_p.w[0][1])*line_x[i] - (max_p.w[0][2]/max_p.w[0][1])

plt.plot(line_x, line_y, color="green")

line_x = np.linspace(0, 5, 20, True)
line_y = np.zeros(line_x.shape)
for i in range(line_x.shape[0]):
    b = (max_p.w[0][0]/max_p.w[0][1]) * chosen_points[0][0][0] + chosen_points[0][0][1]
    line_y[i] = -(max_p.w[0][0]/max_p.w[0][1])*line_x[i] + b

plt.plot(line_x, line_y, color="pink", linestyle="--")

line_x = np.linspace(0, 5, 20, True)
line_y = np.zeros(line_x.shape)
for i in range(line_x.shape[0]):
    b = (max_p.w[0][0]/max_p.w[0][1]) * chosen_points[1][0][0] + chosen_points[1][0][1]
    line_y[i] = -(max_p.w[0][0]/max_p.w[0][1])*line_x[i] + b

plt.plot(line_x, line_y, color="pink", linestyle="--")

#yrange = train_df["Y"].max() - train_df["Y"].min()
#plt.ylim((train_df["Y"].min() - 0.05 * yrange, train_df["Y"].max() + 0.05 * yrange))
plt.ylim(ylim)

#xrange = train_df["X"].max() - train_df["X"].min()
#plt.xlim((train_df["X"].min() - 0.05 * xrange, train_df["X"].max() + 0.05 * xrange))
plt.xlim(xlim)

plt.xlabel("X")
plt.ylabel("Y")
plt.legend(title="Etiqueta", bbox_to_anchor=(1.04, 1), loc="upper left")
plt.title("Recta óptima a partir de la del Perceptrón")
plt.show()

# %%
df = pd.read_csv("./data/TP3-2.csv")
df
# Out:
#            X          Y  Label
# 0   0.865876   4.682152      1
# 1   1.672741   4.874640      1
# 2   0.144147   2.376455      1
# 3   1.472454   2.527801      1
# 4   3.177741   1.771983     -1
# ..       ...        ...    ...
# 95  1.743253   2.828639      1
# 96  3.574628   9.112685     -1
# 97  0.506097  -0.375812     -1
# 98  4.066532  10.612722     -1
# 99  2.703765   6.165316     -1
#
# [100 rows x 3 columns]

# %%
train_df, test_df = k_fold_split(df, 4)

# %%
p, errs, t_errs, init_w = build_step_perceptron(train_df, test_df, "Label", 0.001, iters=100000)

# %%
plt.figure(figsize=(10, 6))
#sns.set_style("darkgrid")
plt.plot(list(range(len(errs))), errs, label="Train")
plt.plot(list(range(len(t_errs))), t_errs, label="Test")
rangey = max(errs) - min(errs)
plt.ylim((0 - 0.05 * rangey, max(errs) + 0.05 * rangey))
plt.xlabel("Iteración")
plt.ylabel("Error cuadrático medio")
plt.title("Error en función de las iteraciones")
plt.legend(title="Tipo", bbox_to_anchor=(1.04, 1), loc="upper left")
plt.show()

# %%
line_x = np.linspace(0, 5, 20, True)
line_y = np.zeros(line_x.shape)
for i in range(line_x.shape[0]):
    line_y[i] = -(p.w[0][0]/p.w[0][1])*line_x[i] - (p.w[0][2]/p.w[0][1])

# %%
plt.figure(figsize=(10, 6))
#sns.set_style("darkgrid")
sns.scatterplot(train_df, x="X", y="Y", hue="Label", palette=sns.color_palette(None, 2), s=50)
sns.scatterplot(test_df, x="X", y="Y", hue="Label", palette=sns.color_palette(None, 2), s=50, marker="^", legend=False)

ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

plt.plot(line_x, line_y, color="green")

#yrange = train_df["Y"].max() - train_df["Y"].min()
#plt.ylim((train_df["Y"].min() - 0.05 * yrange, train_df["Y"].max() + 0.05 * yrange))
plt.ylim(ylim)

#xrange = train_df["X"].max() - train_df["X"].min()
#plt.xlim((train_df["X"].min() - 0.05 * xrange, train_df["X"].max() + 0.05 * xrange))
plt.xlim(xlim)

plt.xlabel("X")
plt.ylabel("Y")
plt.legend(title="Etiqueta", bbox_to_anchor=(1.04, 1), loc="upper left")
plt.title("Recta de separación del Perceptrón")
plt.show()
